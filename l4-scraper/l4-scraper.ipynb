# %% [markdown]
# # Meqasa Scraper

# %%
import re
import datetime
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://meqasa.com/properties-for-rent-in-ghana'
result = requests.get(url)
src  = result.content

# %%
soup = BeautifulSoup(src, 'lxml')

# %%
containers = soup.findAll('div', {'class': 'mqs-featured-prop-inner-wrap'})

# %%
base_url = 'https://meqasa.com'
def house_info(houses_list):
    house_names = []
    house_beds  = []
    house_showers = []
    house_garages = []
    house_areas  = [] 
    house_descriptions = []
    house_prices = []
    house_currencys  = []
    house_rent_periods  = []
    house_urls  = []
    house_address  = []
    house_posted_times = []  
    
    for idx, link in enumerate(houses_list):
        if idx == 20:
            break
            
        prop_features_li = link.find('ul', {'class': 'prop-features'})
        lx1 = prop_features_li.find_all('li')

        page_link = base_url + link.find('a').attrs['href']

        areas, garages, addresses, descriptions, posted_times = extract_from_house_link(page_link)
        
        beds = link.find('ul', {'class': 'prop-features'}).li.text
        showers = lx1[1].text
   
        price_snip  = link.find('p', {'class': 'h3'}).text.strip()
        prices = extract_price(price_snip)
        currency = extract_currency(price_snip)
        periods = extract_period(price_snip)

        house_names.append(link.h2.a['href'].split('/')[1])
        house_beds.append(beds)
        house_showers.append(showers)
        
        house_garages.append(garages)    
        house_areas.append(areas)
        house_descriptions.append(descriptions)
        house_prices.append(prices)
        house_currencys.append(currency)
        house_rent_periods.append(periods)
        
        house_urls.append(base_url + link.find('a').attrs['href'])
        house_address.append(addresses)
        house_posted_times.append(posted_times)

    df_houses = pd.DataFrame({'Property': house_names,
                              'Beds': house_beds,
                              'Showers': house_showers,
                              'Garages': house_garages,
                              'Area': house_areas,
                              'Description': house_descriptions,
                              'Price': house_prices,
                              'Currency': house_currencys,
                              'Rent Period': house_rent_periods,
                              'Url': house_urls,
                              'Address': house_address,
                              'Time Posted': house_posted_times,
                             })
    
    return(df_houses)

# %%
df_house = house_info(containers)

# %%
df_house.head()
# Out:
#                                             Property Beds Showers Garages  \
# 0  townhouse-for-rent-at-Airport-Residential-Area...    4       4       0
# 1  apartment-for-rent-at-Airport-Area-104135?y=63...    3       2       2
# 2    house-for-rent-at-Cantonments-101461?y=63823746    4       4       0
# 3  apartment-for-rent-at-Shiashie,-Accra,-Ghana-0...    1       1       0
# 4  apartment-for-rent-at-Cantonments-101436?y=638...    4       3       0
#
#     Area                                        Description  Price Currency  \
# 0     na  4 bedroom townhouse for rent in Airport Reside...  28890      GH₵
# 1     na  Simply must be on your viewing list!! I’m exci...   3500        $
# 2     na  A contemporary 4-Bedroom Townhouse located in ...   4000        $
# 3  42 m2  Price is GH¢ 7,506 ($1,390) per month inclusiv...   1390        $
# 4     na  A true lifestyle experience offering our cheri...   4000        $
#
#   Rent Period                                                Url  \
# 0       month  https://meqasa.com/townhouse-for-rent-at-Airpo...
# 1       month  https://meqasa.com/apartment-for-rent-at-Airpo...
# 2       month  https://meqasa.com/house-for-rent-at-Cantonmen...
# 3       month  https://meqasa.com/apartment-for-rent-at-Shias...
# 4       month  https://meqasa.com/apartment-for-rent-at-Canto...
#
#                     Address        Time Posted
# 0  Airport Residential Area  November 11, 2019
# 1              Airport Area  November 11, 2019
# 2               Cantonments  November 11, 2019
# 3    Shiashie, Accra, Ghana  November 11, 2019
# 4               Cantonments  November 11, 2019

# %%
def save_data(df):
    file_time = datetime.datetime.now()
    file_time = file_time.strftime('%Y-%m-%d')
    fine_name = 'meqasa_'+file_time+'.csv'
    
    df.to_csv('data/'+fine_name, index=False)

# %%
# 
save_data(df_house)

# %%
# utils
def extract_from_house_link(house_url):
    result = requests.get(house_url)
    src  = result.content
    soup = BeautifulSoup(src, 'lxml')
    container = soup.find('section', {'class': 'span8'})
    
    table_info = get_table_rows_todict(container)
    areas = extract_vals(table_info, 'Area')
    garages = extract_vals(table_info, 'Garage')
    address = extract_vals(table_info, 'Address')
    
    #     
    descriptions = container.p.text.strip()
    
    date_ctr = soup.find('p', {'class': 'listed-by-text'}).text.strip()
    posted_time = extract_date(date_ctr)
    
    return(areas, garages, address, descriptions, posted_time)

# %%
# utils
def extract_price(snip):
    txt = re.sub('[^0-9]','', snip)
    return(txt)

def extract_currency(snip):
    if snip != "Price[Price disclosed on request]":
        start = re.search(r'Price', snip ).end()
        end = re.search(r'[0-9]', snip).start()

        txt = snip[start:end]
    else:
        txt = 'na'
    return(txt)

def extract_period(snip):
    txt = snip.split(" ")[-1].strip()
    return(txt)

# %%
def extract_date(snip):
    start = re.search(r'Updated on ', snip ).end()
    end = re.search(r' by:', snip).start()

    txt = snip[start:end]

    return(txt)

def extract_vals(table_dict, str1):
    if str1 in table_dict:
        txt = table_dict[str1][0]
    else:
        txt = 'na'
    return(txt)

# %%
def get_table_rows_todict(lnk):
    table = lnk.find_all('table')[0]
    rows = table.find_all('tr')
    row_list = []
    for tr in rows:
        td = tr.find_all('td')
        row = [i.text.rstrip() for i in td]
        row_list.append(row)

    row_list.pop(0)
    row_list.pop(0)
    row_list.pop(0)
    return {d[0]: d[1:] for d in row_list}

# %% [markdown]
# ## FIN
#
# ---

# %% [markdown]
# ### SCRATCH

# %%
def extract_price_old(snip):
    if snip is not None:
        start = re.search(r'\nPriceGH₵', snip ).end()
        end = re.search(r' / ', snip).start()

        txt = snip[start:end].strip()
    else:
        txt = 0
    return(txt)

# %%
containers = soup.findAll('div', {'class': 'mqs-featured-prop-inner-wrap'})
a = containers[0]

aa1  = a.find('p', {'class': 'h3'})
aa1.text
# aa1.text.split(" ")[-1].strip()
# Out:
# '\nPriceGH₵28,890 / month\n'

# %%
a5 = extract_price(aa1.text)
a5

# n = None
# a6 = extract_price(n)
# a6
# Out:
# '28,890'

# %%
aq = 'lkdfhisoe78347834 (())&/&745  '
result = re.sub('[^0-9]','', aq)
result
# Out:
# '78347834745'

# %%
qq = '\nPriceGH₵28,890 / month\n'
result = re.sub('[^0-9]','', qq)
result
# Out:
# '28890'

# %%
qq2 = 'Price$2,650 / month'
qq3 = 'Price[Price disclosed on request]'
c3 = extract_currency2(qq3)
c3
# Out:
# 'na'

# %%
def extract_currency2(snip):
    if snip != "Price[Price disclosed on request]":
        start = re.search(r'Price', snip ).end()
        end = re.search(r'[0-9]', snip).start()

        txt = snip[start:end]
    else:
        txt = 'na'
    return(txt)

# %%
# result.content
# soup.title.text
# for t in soup.find_all('a'):
#     print(t.text)
containers = soup.findAll('div', {'class': 'mqs-featured-prop-inner-wrap'})
a = containers[0]
# a.h2.a['href']

b = a.h2.a['href'].split('/')
b[1]
# a.h2.a['href'].split('/')[1]
# 'apartment-for-rent-at-Airport-Area-104135?y=11566372'
# Out:
# 'townhouse-for-rent-at-Airport-Residential-Area-103217?y=2006959929'

# %%
beds  = a.find('ul', {'class': 'prop-features'}).li.text
# beds  = link.find('ul', {'class': 'prop-features'}).div.div.text.split(',')[0].replace('Beds: ','').strip()        
beds
# Out:
# '4'

# %%
# v = click_house_link('https://meqasa.com/apartment-for-rent-at-Cantonments-101436?y=770335285')

# v.find()
# v.p
v.select('li.bed')
v.table()[15].get_text()
v.select('li.shower')[0].find(text=True)

# v.select('table.table td')[0]
table = v.find_all('table')[0]
rows = table.find_all('tr')
# rows

# %%
row_list = []
for tr in rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    row_list.append(row)
    print(row)
# Out:
# ['Categories', 'Apartment for Rent\nApartment for Rent in East Cantonments']
# ['']
# ['\xa0\xa0\xa0\xa0 12 months @ $ 4,000/month (GH₵ 22,100)']
# ['Bedrooms', '4']
# ['Bathrooms', '3']
# ['Garage', '0']
# ['Air conditioning\nCooker\nRefrigerator\nMicrowave\nInternet\nGarden\nSwimming pool\nSecurity service\nGenerator\nWater reservoir\n']
# ['Address', 'Cantonments']
# ['101436']

# %%
# showers  = a.find('ul', {'class': 'prop-features'})
# showers

a1  = a.find('ul', {'class': 'prop-features'})
a2 = a1.find_all('li')
a2
# a2[1].text
# a2[2].text
# Out:
# [<li class="bed"><span>3</span></li>,
#  <li class="shower"><span>2</span></li>,
#  <li class="garage" title="Garages"><span>2</span></li>,
#  <li class="reduced sl104135 fav-icon"><a data-target="#fav-modal" data-toggle="modal" href=""><img alt="Unfavourite" src="https://dve7rykno93gs.cloudfront.net/assets2/images/fav-icon.png" title="Add to favourites"/></a></li>]

# %%
c1 = containers[1]
c12 = c1.find('ul', {'class': 'prop-features'})
c122 = c12.find_all('li')
c122
# Out:
# [<li class="bed"><span>4</span></li>,
#  <li class="shower"><span>4</span></li>,
#  <li class="reduced sl103217 fav-icon"><a data-target="#fav-modal" data-toggle="modal" href=""><img alt="Unfavourite" src="https://dve7rykno93gs.cloudfront.net/assets2/images/fav-icon.png" title="Add to favourites"/></a></li>]

# %% [markdown]
# if c122 has title=='Garages':
#     c122[2].text

# %%
if a2[2].has_attr('title'):
# if c122[2].has_attr('title'):
    if a2[2].title == 'Garages':
        print('ok')

# %%
a2[2].attrs['title']
# Out:
# 'Garages'

# %% [markdown]
# `<li title="Garages" class="garage"><span>2</span></li>`

# %%
# listings = containers.find_all('div', {'class': 'mqs-prop-dt-wrapper'})
# containers'apartment-for-rent-at-Airport-Area-104135?y=11566372'
# listings
# listings = soup.find_all('li', {'class': 'normal--2QYVk gtm-normal-ad'})
# ref = listings.findAll('div', {'class': 'mqs-prop-dt-wrapper'})

# %%
tag = a2[2].find(lambda tag: tag.name == 'li' and tag['class'] == ['garage'])
# filter(bool, tag['class']) == ['value', 'price']

# %%
tag

# %%
mqs-prop-dt-wrapper

# %%
# px  = containers.findAll('div', {'class': 'mqs-prop-dt-wrapper'})
px0 = containers[0]
px01 = px0.find('div', {'class': 'mqs-prop-dt-wrapper'})
# px01.p.span.text
px01
# Out:
# <div class="mqs-prop-dt-wrapper">
# <h2>
# <a href="/apartment-for-rent-at-Airport-Area-104135?y=11566372">3 bedroom furnished apartment for rent at Airport Area, Ghana</a>
# </h2>
# <p class="h3">
# <span class="h3">Price</span>$3,500 <span>/ month</span>
# </p>
# <p>Simply must be on your viewing list!! I’m excited to market ...</p>
# <ul class="prop-features">
# <li class="bed"><span>3</span></li>
# <li class="shower"><span>2</span></li>
# <li class="garage" title="Garages"><span>2</span></li>
# <li class="reduced sl104135 fav-icon"><a data-target="#fav-modal" data-toggle="modal" href=""><img alt="Unfavourite" src="https://dve7rykno93gs.cloudfront.net/assets2/images/fav-icon.png" title="Add to favourites"/></a></li>
# </ul>
# </div>

# %%
df_house
# Out:
#                                              Property Beds Showers   Garages  \
# 0   townhouse-for-rent-at-Airport-Residential-Area...    4       4
# 1   apartment-for-rent-at-Airport-Residential-Area...    2       2    120 m2
# 2   apartment-for-rent-at-Spintex-(-studio-apartme...    1       1    200 m2
# 3   house-for-rent-at-Adjiringanor-104427?y=200695...    5       4         1
# 4   apartment-for-rent-at-Airport-Area-104135?y=20...    3       2         2
# 5   apartment-for-rent-at-Cantonments-101436?y=200...    4       3
# 6   townhouse-for-rent-at-Cantonments-074711?y=200...    4       4
# 7   house-for-rent-at-Cantonments-101461?y=2006959929    4       4
# 8   apartment-for-rent-at-Shiashie,-Accra,-Ghana-0...    1       1     42 m2
# 9   apartment-for-rent-at-West-Legon-104998?y=2006...    2       2         4
# 10  apartment-for-rent-at-West-Legon-104999?y=2006...    3       3         3
# 11  house-for-rent-at-Airport-Hills,-Accra,-Ghana-...    4       5    300 m2
# 12  apartment-for-rent-at-Cantonments-102485?y=200...    3       3         2
# 13  apartment-for-rent-at-Ridge,Accra,Ghana.-10260...    3       3    160 m2
# 14  apartment-for-rent-at-East-Legon-101322?y=2006...    2       2         2
# 15      house-for-rent-at-Amrahia-080665?y=2006959929    5       5
# 16          house-for-rent-at-Osu-101329?y=2006959929    3       2
# 17  house-for-rent-at-East-Legon-A&C-mall--100656?...    4       5    650 m2
# 18       house-for-rent-at-Adenta-105095?y=2006959929    7       8
# 19  apartment-for-rent-at-Roman-Ridge-081250?y=200...    3       3
# 20  commercial space-for-rent-at-Tema-081254?y=200...
# 21  apartment-for-rent-at-Spintex-085007?y=2006959929    2       2
# 22  commercial space-for-rent-at-Airport-Residenti...
# 23  office-for-rent-at-Tema-Community-1-085475?y=2...
# 24  apartment-for-rent-at-North-Legon-102046?y=200...    3       4         3
# 25     apartment-for-rent-at--Osu-096661?y=2006959929    2       2         1
# 26    house-for-rent-at-Trassaco--033763?y=2006959929    6       6         2
# 27   house-for-rent-at-East-Legon-102265?y=2006959929    6       4         1
# 28  house-for-rent-at-Dovehill-Estate,-Spintex-Roa...    4       5         1
# 29  apartment-for-rent-at-Airport-Residential-Area...    3       3    180 m2
# ..                                                ...  ...     ...       ...
# 63  townhouse-for-rent-at-Cantonments-098136?y=200...    3       4         1
# 64  apartment-for-rent-at-Prampram-101933?y=200695...    2       2
# 65  office-for-rent-at-Alhaji-Station-099223?y=200...    2       1
# 66  apartment-for-rent-at-East-Legon-091843?y=2006...    3       3
# 67  house-for-rent-at-Community-22-100582?y=200695...    5       6
# 68  house-for-rent-at-East-Legon--094046?y=2006959929    3       3
# 69      apartment-for-rent-at-Osu-094225?y=2006959929    3       3    180 m2
# 70  apartment-for-rent-at-Cantonments-093460?y=200...    2       2         1
# 71  house-for-rent-at-East-Legon-Hills-098577?y=20...    6       5         1
# 72  apartment-for-rent-at-Airport-Residential-Area...    3       4         1
# 73  townhouse-for-rent-at-East-Legon-066504?y=2006...    4       4
# 74          land-for-rent-at-Nima-099029?y=2006959929                 638 m2
# 75  2-bedroom-apartment-for-rent-in-Cantonments-un...    2       3         2
# 76  1-bedroom-apartment-for-rent-in-Cantonments-un...    1       1         1
# 77  townhouse-for-rent-at-Cantonments-103616?y=200...    4       4
# 78  house-for-rent-at-Adjiringanor-104427?y=200695...    5       4         1
# 79    townhouse-for-rent-at-RIDGE-103404?y=2006959929    5       5
# 80  apartment-for-rent-at-Spintex--(-studio-apartm...    1       1    200 m2
# 81     house-for-rent-at-Trasacco-099541?y=2006959929    4       5         2
# 82  apartment-for-rent-at-Cantonments-067174?y=200...    2       2         1
# 83  apartment-for-rent-at-West-Legon-104999?y=2006...    3       3         3
# 84  apartment-for-rent-at-Cantonments-093451?y=200...    2       2         1
# 85  apartment-for-rent-at-Airport-Residential-Area...    3       3         2
# 86       house-for-rent-at-Adenta-105095?y=2006959929    7       8
# 87  apartment-for-rent-at-Lagos-Avenue-040237?y=20...    1       1  1,000 m2
# 88  house-for-rent-at-East-Legon--099843?y=2006959929    5       6         1
# 89          house-for-rent-at-Osu-101329?y=2006959929    3       2
# 90      house-for-rent-at-Amrahia-080665?y=2006959929    5       5
# 91  apartment-for-rent-at-Roman-Ridge-081250?y=200...    3       3
# 92     house-for-rent-at-Oyarifa--103549?y=2006959929    3       3         2
#
#                                                   Url
# 0   https://meqasa.com/townhouse-for-rent-at-Airpo...
# 1   https://meqasa.com/apartment-for-rent-at-Airpo...
# 2   https://meqasa.com/apartment-for-rent-at-Spint...
# 3   https://meqasa.com/house-for-rent-at-Adjiringa...
# 4   https://meqasa.com/apartment-for-rent-at-Airpo...
# 5   https://meqasa.com/apartment-for-rent-at-Canto...
# 6   https://meqasa.com/townhouse-for-rent-at-Canto...
# 7   https://meqasa.com/house-for-rent-at-Cantonmen...
# 8   https://meqasa.com/apartment-for-rent-at-Shias...
# 9   https://meqasa.com/apartment-for-rent-at-West-...
# 10  https://meqasa.com/apartment-for-rent-at-West-...
# 11  https://meqasa.com/house-for-rent-at-Airport-H...
# 12  https://meqasa.com/apartment-for-rent-at-Canto...
# 13  https://meqasa.com/apartment-for-rent-at-Ridge...
# 14  https://meqasa.com/apartment-for-rent-at-East-...
# 15  https://meqasa.com/house-for-rent-at-Amrahia-0...
# 16  https://meqasa.com/house-for-rent-at-Osu-10132...
# 17  https://meqasa.com/house-for-rent-at-East-Lego...
# 18  https://meqasa.com/house-for-rent-at-Adenta-10...
# 19  https://meqasa.com/apartment-for-rent-at-Roman...
# 20  https://meqasa.com/commercial space-for-rent-a...
# 21  https://meqasa.com/apartment-for-rent-at-Spint...
# 22  https://meqasa.com/commercial space-for-rent-a...
# 23  https://meqasa.com/office-for-rent-at-Tema-Com...
# 24  https://meqasa.com/apartment-for-rent-at-North...
# 25  https://meqasa.com/apartment-for-rent-at--Osu-...
# 26  https://meqasa.com/house-for-rent-at-Trassaco-...
# 27  https://meqasa.com/house-for-rent-at-East-Lego...
# 28  https://meqasa.com/house-for-rent-at-Dovehill-...
# 29  https://meqasa.com/apartment-for-rent-at-Airpo...
# ..                                                ...
# 63  https://meqasa.com/townhouse-for-rent-at-Canto...
# 64  https://meqasa.com/apartment-for-rent-at-Pramp...
# 65  https://meqasa.com/office-for-rent-at-Alhaji-S...
# 66  https://meqasa.com/apartment-for-rent-at-East-...
# 67  https://meqasa.com/house-for-rent-at-Community...
# 68  https://meqasa.com/house-for-rent-at-East-Lego...
# 69  https://meqasa.com/apartment-for-rent-at-Osu-0...
# 70  https://meqasa.com/apartment-for-rent-at-Canto...
# 71  https://meqasa.com/house-for-rent-at-East-Lego...
# 72  https://meqasa.com/apartment-for-rent-at-Airpo...
# 73  https://meqasa.com/townhouse-for-rent-at-East-...
# 74  https://meqasa.com/land-for-rent-at-Nima-09902...
# 75  https://meqasa.com/2-bedroom-apartment-for-ren...
# 76  https://meqasa.com/1-bedroom-apartment-for-ren...
# 77  https://meqasa.com/townhouse-for-rent-at-Canto...
# 78  https://meqasa.com/house-for-rent-at-Adjiringa...
# 79  https://meqasa.com/townhouse-for-rent-at-RIDGE...
# 80  https://meqasa.com/apartment-for-rent-at-Spint...
# 81  https://meqasa.com/house-for-rent-at-Trasacco-...
# 82  https://meqasa.com/apartment-for-rent-at-Canto...
# 83  https://meqasa.com/apartment-for-rent-at-West-...
# 84  https://meqasa.com/apartment-for-rent-at-Canto...
# 85  https://meqasa.com/apartment-for-rent-at-Airpo...
# 86  https://meqasa.com/house-for-rent-at-Adenta-10...
# 87  https://meqasa.com/apartment-for-rent-at-Lagos...
# 88  https://meqasa.com/house-for-rent-at-East-Lego...
# 89  https://meqasa.com/house-for-rent-at-Osu-10132...
# 90  https://meqasa.com/house-for-rent-at-Amrahia-0...
# 91  https://meqasa.com/apartment-for-rent-at-Roman...
# 92  https://meqasa.com/house-for-rent-at-Oyarifa--...
#
# [93 rows x 5 columns]

# %%
vc = click_house_link('https://meqasa.com/apartment-for-rent-at-Cantonments-101436?y=770335285')
# Out:
# <div class="property-box">
# <div class="top">
# <div class="row">
# <div class="top-2-colums-details">
# <div class="prop-top-header">
# <div class="top-details-wrapper">
# <span typeof="v:Breadcrumb"><a href="/" property="v:title" rel="v:url">Home</a></span> »
# <span typeof="v:Breadcrumb"><a href="/properties-for-rent-in-ghana" property="v:title" rel="v:url">For Rent</a></span> »
# <span typeof="v:Breadcrumb"><a href="/apartments-for-rent-in-ghana" property="v:title" rel="v:url">Apartments</a></span> »
# <span typeof="v:Breadcrumb"><a href="/apartments-for-rent-in-Greater Accra-region" property="v:title" rel="v:url">Greater Accra region</a></span> »
# <span typeof="v:Breadcrumb"><a href="/apartments-for-rent-in-East Cantonments" property="v:title" rel="v:url">East Cantonments</a></span> »
# <span typeof="v:Breadcrumb"><a href="4-bedroom-apartments-for-rent-in-East Cantonments" property="v:title" rel="v:url">4-bedroom</a></span> »
# <h1>4 bedroom apartment for rent at Cantonments</h1>
# </div>
# <div class="price-wrapper">
# <div class="price">$ 4,000</div>
# <div class="rate">/ month</div></div></div>
# <div class="property-slider-wrapper">
# <div class="prop-main-slider" id="slider1_container" style="position: relative; top: 0px; left: 0px; width: 960px; height: 540px; background: #191919; overflow: hidden;">
# <div style="position: absolute; top: 0px; left: 0px;" u="loading">
# <div style="filter: alpha(opacity=70); opacity:0.7; position: absolute; display: block; background-color: #000000; top: 0px; left: 0px;width: 100%;height:100%;">
# </div>
# <div style="position: absolute; display: block; background: url(/assets2/images/ajl.gif) no-repeat center center; top: 0px; left: 0px;width: 100%;height:100%;">
# </div></div>
# <div style="cursor: move; position: absolute; left: 240px; top: 0px; width: 720px; height: 540px; overflow: hidden;" u="slides">
# <div><img alt="Property photo 1" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143600" u="image"/></div>
# <div><img alt="Property photo 2" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143601" u="image"/></div>
# <div><img alt="Property photo 3" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143602" u="image"/></div>
# <div><img alt="Property photo 4" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143603" u="image"/></div>
# <div><img alt="Property photo 5" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143604" u="image"/></div>
# <div><img alt="Property photo 6" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143605" u="image"/></div>
# <div><img alt="Property photo 7" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143606" u="image"/></div>
# <div><img alt="Property photo 8" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143607" u="image"/></div>
# <div><img alt="Property photo 9" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143608" u="image"/></div>
# <div><img alt="Property photo 10" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143609" u="image"/></div>
# <div><img alt="Property photo 11" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143610" u="image"/></div>
# <div><img alt="Property photo 12" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143611" u="image"/></div>
# <div><img alt="Property photo 13" src="https://dve7rykno93gs.cloudfront.net/temp/temp/10143612" u="image"/></div>
# </div>
# <span class="jssora05l" style="width: 40px; height: 40px; top: 158px; left: 248px;" u="arrowleft">
# </span>
# <span class="jssora05r" style="width: 40px; height: 40px; top: 158px; right: 8px" u="arrowright">
# </span>
# <div class="jssort02" style="position: absolute; width: 240px; height: 540px; left:0px; bottom: 0px;" u="thumbnavigator">
# <div style="cursor: move;" u="slides">
# <div class="p" style="position: absolute; width: 99px; height: 66px; top: 0; left: 0;" u="prototype">
# <div class="w">
# <thumbnailtemplate style=" width: 100%; height: 100%; border: none;position:absolute; top: 0; left: 0;">
# </thumbnailtemplate>
# </div>
# <div class="c"></div></div></div></div></div>
# <div class="title-line">
# <div class="down-details-wrap2">
# <ul class="prop-features">
# <li class="bed"><span>4</span></li>
# <li class="shower"><span>3</span></li>
# <li class="reduced sl101436 fav-icon"><a data-target="#fav-modal" data-toggle="modal" href=""><img alt="Unfavourite" src="https://dve7rykno93gs.cloudfront.net/assets2/images/fav-icon.png" title="Add to favourites"/></a></li>
# </ul>
# </div></div></div></div></div></div></div>
